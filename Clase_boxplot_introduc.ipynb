# %% [markdown]
# <a href="https://colab.research.google.com/github/Juan-Vega18/INTRODUC.-CIENCIA-DE-DATOS/blob/main/Clase_boxplot_introduc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats

# %%
#Rango intercuartilico

#IQR = Q3-Q1
#Lim inf = Q1 - 1.5 * IQR
#Lim sup = Q3 + 1.5 * IQR

# %%
#Data de ejemplo.
#Lo que queremos hacer aquí es hacer un boxplot de forma manual, para eso, definimos la data de forma manual, es un diccionario con departamento y
#salario.

data = {
    "Department": ["Data", "Data", "Data", "Data", "Data",
                   "Marketing", "Marketing", "Marketing", "Marketing", "Marketing",
                   "Engineering", "Engineering", "Engineering", "Engineering", "Engineering"],

    "Salary": [4500, 4700, 5000, 5200, 12000,
               3000, 3200, 3100, 3300, 9000,
               6000, 6200, 6100, 6300, 6400]
}
#Creamos el dataframe.
df = pd.DataFrame(data)

#Crear boxplot
colums = df.groupby('Department')['Salary'] #Agrupamos y definimos las columnas
colums.agg(['mean', 'median', 'min', 'max', 'std']) #Añadimos 5 columnas con nombre de cada estadístico
print(df.groupby('Department')['Salary'].describe()) #Usamos la función describe de cada departamento con su salario
boxplot = df.boxplot(column='Salary', by='Department') #Hacemos el boxplot

median_salary = df['Salary'].median() #Función para calcular la mediana de una columna
#print(f'La media del salario es: ', mean_salary)

#Encontrar outliers. Buscamos valores superiores a 2 desviaciones estandar
df['z_score_value'] = np.abs(zscore(df['Salary']))
df['z_score_value'].astype(float)
outliers = df['z_score_value'] > 2
print(outliers)
# Out:
#              count    mean          std     min     25%     50%     75%  \
# Department
# Data           5.0  6280.0  3208.893890  4500.0  4700.0  5000.0  5200.0
# Engineering    5.0  6200.0   158.113883  6000.0  6100.0  6200.0  6300.0
# Marketing      5.0  4320.0  2618.587405  3000.0  3100.0  3200.0  3300.0
#
#                  max
# Department
# Data         12000.0
# Engineering   6400.0
# Marketing     9000.0
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# Name: z_score_value, dtype: bool
